# %%
import torch

# %%
# Control Variable
save1_or_load0 = False # save1_or_load0 = True means to Train and Save the weights
                      # save1_or_load0 = False means Load the weights and Test

# %%
! pip install "lightning-bolts"
# Out:
# Collecting lightning-bolts
#   Downloading lightning_bolts-0.7.0-py3-none-any.whl.metadata (9.5 kB)
# Requirement already satisfied: numpy in c:\users\rrpalani\.conda\envs\pytorch_env\lib\site-packages (from lightning-bolts) (1.26.4)
# Collecting pytorch-lightning<2.0.0,>1.7.0 (from lightning-bolts)
#   Downloading pytorch_lightning-1.9.5-py3-none-any.whl.metadata (23 kB)
# Collecting torchmetrics (from lightning-bolts)
#   Downloading torchmetrics-1.4.0-py3-none-any.whl.metadata (19 kB)
# Collecting lightning-utilities>0.3.1 (from lightning-bolts)
#   Downloading lightning_utilities-0.11.2-py3-none-any.whl.metadata (4.7 kB)
# Collecting torchvision>=0.10.0 (from lightning-bolts)
#   Downloading torchvision-0.18.0-cp310-cp310-win_amd64.whl.metadata (6.6 kB)
# Collecting tensorboard>=2.9.1 (from lightning-bolts)
#   Downloading tensorboard-2.16.2-py3-none-any.whl.metadata (1.6 kB)
# Requirement already satisfied: packaging>=17.1 in c:\users\rrpalani\.conda\envs\pytorch_env\lib\site-packages (from lightning-utilities>0.3.1->lightning-bolts) (23.2)
# Requirement already satisfied: setuptools in c:\users\rrpalani\.conda\envs\pytorch_env\lib\site-packages (from lightning-utilities>0.3.1->lightning-bolts) (69.5.1)
# Requirement already satisfied: typing-extensions in c:\users\rrpalani\.conda\envs\pytorch_env\lib\site-packages (from lightning-utilities>0.3.1->lightning-bolts) (4.11.0)
# Requirement already satisfied: torch>=1.10.0 in c:\users\rrpalani\.conda\envs\pytorch_env\lib\site-packages (from pytorch-lightning<2.0.0,>1.7.0->lightning-bolts) (2.2.0)
# Requirement already satisfied: tqdm>=4.57.0 in c:\users\rrpalani\.conda\envs\pytorch_env\lib\site-packages (from pytorch-lightning<2.0.0,>1.7.0->lightning-bolts) (4.66.2)
# Requirement already satisfied: PyYAML>=5.4 in c:\users\rrpalani\.conda\envs\pytorch_env\lib\site-packages (from pytorch-lightning<2.0.0,>1.7.0->lightning-bolts) (6.0.1)
# Requirement already satisfied: fsspec>2021.06.0 in c:\users\rrpalani\.conda\envs\pytorch_env\lib\site-packages (from fsspec[http]>2021.06.0->pytorch-lightning<2.0.0,>1.7.0->lightning-bolts) (2024.3.1)
# Collecting absl-py>=0.4 (from tensorboard>=2.9.1->lightning-bolts)
#   Downloading absl_py-2.1.0-py3-none-any.whl.metadata (2.3 kB)
# Collecting grpcio>=1.48.2 (from tensorboard>=2.9.1->lightning-bolts)
#   Downloading grpcio-1.63.0-cp310-cp310-win_amd64.whl.metadata (3.3 kB)
# Requirement already satisfied: markdown>=2.6.8 in c:\users\rrpalani\.conda\envs\pytorch_env\lib\site-packages (from tensorboard>=2.9.1->lightning-bolts) (3.4.1)
# Requirement already satisfied: protobuf!=4.24.0,>=3.19.6 in c:\users\rrpalani\.conda\envs\pytorch_env\lib\site-packages (from tensorboard>=2.9.1->lightning-bolts) (3.20.3)
# Requirement already satisfied: six>1.9 in c:\users\rrpalani\.conda\envs\pytorch_env\lib\site-packages (from tensorboard>=2.9.1->lightning-bolts) (1.16.0)
# Collecting tensorboard-data-server<0.8.0,>=0.7.0 (from tensorboard>=2.9.1->lightning-bolts)
#   Downloading tensorboard_data_server-0.7.2-py3-none-any.whl.metadata (1.1 kB)
# Requirement already satisfied: werkzeug>=1.0.1 in c:\users\rrpalani\.conda\envs\pytorch_env\lib\site-packages (from tensorboard>=2.9.1->lightning-bolts) (2.2.3)
# Collecting pretty-errors==1.2.25 (from torchmetrics->lightning-bolts)
#   Downloading pretty_errors-1.2.25-py3-none-any.whl.metadata (12 kB)
# Requirement already satisfied: colorama in c:\users\rrpalani\.conda\envs\pytorch_env\lib\site-packages (from pretty-errors==1.2.25->torchmetrics->lightning-bolts) (0.4.6)
# Collecting torch>=1.10.0 (from pytorch-lightning<2.0.0,>1.7.0->lightning-bolts)
#   Downloading torch-2.3.0-cp310-cp310-win_amd64.whl.metadata (26 kB)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in c:\users\rrpalani\.conda\envs\pytorch_env\lib\site-packages (from torchvision>=0.10.0->lightning-bolts) (10.3.0)
# Requirement already satisfied: filelock in c:\users\rrpalani\.conda\envs\pytorch_env\lib\site-packages (from torch>=1.10.0->pytorch-lightning<2.0.0,>1.7.0->lightning-bolts) (3.13.1)
# Requirement already satisfied: sympy in c:\users\rrpalani\.conda\envs\pytorch_env\lib\site-packages (from torch>=1.10.0->pytorch-lightning<2.0.0,>1.7.0->lightning-bolts) (1.12)
# Requirement already satisfied: networkx in c:\users\rrpalani\.conda\envs\pytorch_env\lib\site-packages (from torch>=1.10.0->pytorch-lightning<2.0.0,>1.7.0->lightning-bolts) (3.1)
# Requirement already satisfied: jinja2 in c:\users\rrpalani\.conda\envs\pytorch_env\lib\site-packages (from torch>=1.10.0->pytorch-lightning<2.0.0,>1.7.0->lightning-bolts) (3.1.3)
# Collecting mkl<=2021.4.0,>=2021.1.1 (from torch>=1.10.0->pytorch-lightning<2.0.0,>1.7.0->lightning-bolts)
#   Downloading mkl-2021.4.0-py2.py3-none-win_amd64.whl.metadata (1.4 kB)
# Requirement already satisfied: aiohttp!=4.0.0a0,!=4.0.0a1 in c:\users\rrpalani\.conda\envs\pytorch_env\lib\site-packages (from fsspec[http]>2021.06.0->pytorch-lightning<2.0.0,>1.7.0->lightning-bolts) (3.9.5)
# Requirement already satisfied: MarkupSafe>=2.1.1 in c:\users\rrpalani\.conda\envs\pytorch_env\lib\site-packages (from werkzeug>=1.0.1->tensorboard>=2.9.1->lightning-bolts) (2.1.3)
# Requirement already satisfied: aiosignal>=1.1.2 in c:\users\rrpalani\.conda\envs\pytorch_env\lib\site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>2021.06.0->pytorch-lightning<2.0.0,>1.7.0->lightning-bolts) (1.2.0)
# Requirement already satisfied: attrs>=17.3.0 in c:\users\rrpalani\.conda\envs\pytorch_env\lib\site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>2021.06.0->pytorch-lightning<2.0.0,>1.7.0->lightning-bolts) (23.1.0)
# Requirement already satisfied: frozenlist>=1.1.1 in c:\users\rrpalani\.conda\envs\pytorch_env\lib\site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>2021.06.0->pytorch-lightning<2.0.0,>1.7.0->lightning-bolts) (1.4.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in c:\users\rrpalani\.conda\envs\pytorch_env\lib\site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>2021.06.0->pytorch-lightning<2.0.0,>1.7.0->lightning-bolts) (6.0.4)
# Requirement already satisfied: yarl<2.0,>=1.0 in c:\users\rrpalani\.conda\envs\pytorch_env\lib\site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>2021.06.0->pytorch-lightning<2.0.0,>1.7.0->lightning-bolts) (1.9.3)
# Requirement already satisfied: async-timeout<5.0,>=4.0 in c:\users\rrpalani\.conda\envs\pytorch_env\lib\site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>2021.06.0->pytorch-lightning<2.0.0,>1.7.0->lightning-bolts) (4.0.3)
# Collecting intel-openmp==2021.* (from mkl<=2021.4.0,>=2021.1.1->torch>=1.10.0->pytorch-lightning<2.0.0,>1.7.0->lightning-bolts)
#   Downloading intel_openmp-2021.4.0-py2.py3-none-win_amd64.whl.metadata (1.2 kB)
# Collecting tbb==2021.* (from mkl<=2021.4.0,>=2021.1.1->torch>=1.10.0->pytorch-lightning<2.0.0,>1.7.0->lightning-bolts)
#   Downloading tbb-2021.12.0-py3-none-win_amd64.whl.metadata (1.1 kB)
# Requirement already satisfied: mpmath>=0.19 in c:\users\rrpalani\.conda\envs\pytorch_env\lib\site-packages (from sympy->torch>=1.10.0->pytorch-lightning<2.0.0,>1.7.0->lightning-bolts) (1.3.0)
# Requirement already satisfied: idna>=2.0 in c:\users\rrpalani\.conda\envs\pytorch_env\lib\site-packages (from yarl<2.0,>=1.0->aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>2021.06.0->pytorch-lightning<2.0.0,>1.7.0->lightning-bolts) (3.7)
# Downloading lightning_bolts-0.7.0-py3-none-any.whl (300 kB)
#    ---------------------------------------- 0.0/300.8 kB ? eta -:--:--
#    ----------------------- ---------------- 174.1/300.8 kB 5.3 MB/s eta 0:00:01
#    ---------------------------------------- 300.8/300.8 kB 4.6 MB/s eta 0:00:00
# Downloading lightning_utilities-0.11.2-py3-none-any.whl (26 kB)
# Downloading pytorch_lightning-1.9.5-py3-none-any.whl (829 kB)
#    ---------------------------------------- 0.0/829.5 kB ? eta -:--:--
#    --------------------------------------  829.4/829.5 kB 17.4 MB/s eta 0:00:01
#    --------------------------------------- 829.5/829.5 kB 13.2 MB/s eta 0:00:00
# Downloading tensorboard-2.16.2-py3-none-any.whl (5.5 MB)
#    ---------------------------------------- 0.0/5.5 MB ? eta -:--:--
#    ------------- -------------------------- 1.8/5.5 MB 59.1 MB/s eta 0:00:01
#    ----------------------------- ---------- 4.0/5.5 MB 51.5 MB/s eta 0:00:01
#    ---------------------------------------  5.5/5.5 MB 49.8 MB/s eta 0:00:01
#    ---------------------------------------- 5.5/5.5 MB 38.9 MB/s eta 0:00:00
# Downloading torchmetrics-1.4.0-py3-none-any.whl (868 kB)
#    ---------------------------------------- 0.0/868.8 kB ? eta -:--:--
#    --------------------------------------- 868.8/868.8 kB 27.7 MB/s eta 0:00:00
# Downloading pretty_errors-1.2.25-py3-none-any.whl (17 kB)
# Downloading torchvision-0.18.0-cp310-cp310-win_amd64.whl (1.2 MB)
#    ---------------------------------------- 0.0/1.2 MB ? eta -:--:--
#    ---------------------------------------- 1.2/1.2 MB 24.8 MB/s eta 0:00:00
# Downloading torch-2.3.0-cp310-cp310-win_amd64.whl (159.8 MB)
#    ---------------------------------------- 0.0/159.8 MB ? eta -:--:--
#    ---------------------------------------- 2.0/159.8 MB 42.3 MB/s eta 0:00:04
#     --------------------------------------- 3.9/159.8 MB 42.0 MB/s eta 0:00:04
#    - -------------------------------------- 4.9/159.8 MB 34.8 MB/s eta 0:00:05
#    - -------------------------------------- 6.3/159.8 MB 33.8 MB/s eta 0:00:05
#    -- ------------------------------------- 8.7/159.8 MB 37.1 MB/s eta 0:00:05
#    -- ------------------------------------- 10.4/159.8 MB 36.4 MB/s eta 0:00:05
#    -- ------------------------------------- 11.5/159.8 MB 32.7 MB/s eta 0:00:05
#    --- ------------------------------------ 13.2/159.8 MB 32.7 MB/s eta 0:00:05
#    --- ------------------------------------ 13.9/159.8 MB 32.8 MB/s eta 0:00:05
#    --- ------------------------------------ 14.9/159.8 MB 29.8 MB/s eta 0:00:05
#    ---- ----------------------------------- 19.4/159.8 MB 38.6 MB/s eta 0:00:04
#    ----- ---------------------------------- 22.2/159.8 MB 46.7 MB/s eta 0:00:03
#    ------ --------------------------------- 24.3/159.8 MB 65.6 MB/s eta 0:00:03
#    ------ --------------------------------- 24.4/159.8 MB 59.5 MB/s eta 0:00:03
#    ------ --------------------------------- 25.5/159.8 MB 43.5 MB/s eta 0:00:04
#    ------- -------------------------------- 29.3/159.8 MB 40.9 MB/s eta 0:00:04
#    ------- -------------------------------- 31.4/159.8 MB 40.9 MB/s eta 0:00:04
#    -------- ------------------------------- 33.5/159.8 MB 38.6 MB/s eta 0:00:04
#    -------- ------------------------------- 35.6/159.8 MB 54.7 MB/s eta 0:00:03
#    --------- ------------------------------ 37.7/159.8 MB 50.4 MB/s eta 0:00:03
#    --------- ------------------------------ 39.8/159.8 MB 43.7 MB/s eta 0:00:03
#    ---------- ----------------------------- 41.9/159.8 MB 43.5 MB/s eta 0:00:03
#    ---------- ----------------------------- 43.9/159.8 MB 43.5 MB/s eta 0:00:03
#    ----------- ---------------------------- 46.0/159.8 MB 43.5 MB/s eta 0:00:03
#    ------------ --------------------------- 48.1/159.8 MB 43.7 MB/s eta 0:00:03
#    ------------ --------------------------- 50.2/159.8 MB 43.7 MB/s eta 0:00:03
#    ------------- -------------------------- 52.3/159.8 MB 43.7 MB/s eta 0:00:03
#    ------------- -------------------------- 54.4/159.8 MB 43.7 MB/s eta 0:00:03
#    -------------- ------------------------- 56.6/159.8 MB 43.7 MB/s eta 0:00:03
#    -------------- ------------------------- 58.7/159.8 MB 43.5 MB/s eta 0:00:03
#    --------------- ------------------------ 60.8/159.8 MB 43.5 MB/s eta 0:00:03
#    --------------- ------------------------ 62.8/159.8 MB 43.5 MB/s eta 0:00:03
#    ---------------- ----------------------- 65.0/159.8 MB 43.7 MB/s eta 0:00:03
#    ---------------- ----------------------- 67.1/159.8 MB 43.7 MB/s eta 0:00:03
#    ----------------- ---------------------- 69.2/159.8 MB 43.7 MB/s eta 0:00:03
#    ----------------- ----------------------
win_amd64.whl (3.9 MB)
#    ---------------------------------------- 0.0/3.9 MB ? eta -:--:--
#    ----------------------- ---------------- 2.3/3.9 MB 72.0 MB/s eta 0:00:01
#    ---------------------------------------  3.9/3.9 MB 49.9 MB/s eta 0:00:01
#    ---------------------------------------- 3.9/3.9 MB 41.4 MB/s eta 0:00:00
# Downloading tensorboard_data_server-0.7.2-py3-none-any.whl (2.4 kB)
# Downloading mkl-2021.4.0-py2.py3-none-win_amd64.whl (228.5 MB)
#    ---------------------------------------- 0.0/228.5 MB ? eta -:--:--
#    ---------------------------------------- 2.4/228.5 MB 51.4 MB/s eta 0:00:05
#     --------------------------------------- 4.5/228.5 MB 57.2 MB/s eta 0:00:04
#    - -------------------------------------- 6.6/228.5 MB 52.8 MB/s eta 0:00:05
#    - -------------------------------------- 8.6/228.5 MB 50.5 MB/s eta 0:00:05
#    - -------------------------------------- 10.8/228.5 MB 46.9 MB/s eta 0:00:05
#    -- ------------------------------------- 12.8/228.5 MB 46.7 MB/s eta 0:00:05
#    -- ------------------------------------- 15.0/228.5 MB 43.5 MB/s eta 0:00:05
#    -- ------------------------------------- 17.0/228.5 MB 46.7 MB/s eta 0:00:05
#    --- ------------------------------------ 19.1/228.5 MB 46.7 MB/s eta 0:00:05
#    --- ------------------------------------ 21.2/228.5 MB 46.7 MB/s eta 0:00:05
#    ---- ----------------------------------- 22.9/228.5 MB 43.5 MB/s eta 0:00:05
#    ---- ----------------------------------- 25.4/228.5 MB 46.9 MB/s eta 0:00:05
#    ---- ----------------------------------- 27.5/228.5 MB 46.9 MB/s eta 0:00:05
#    ----- ---------------------------------- 29.7/228.5 MB 43.5 MB/s eta 0:00:05
#    ----- ---------------------------------- 31.2/228.5 MB 43.7 MB/s eta 0:00:05
#    ----- ---------------------------------- 31.2/228.5 MB 43.7 MB/s eta 0:00:05
#    ------ --------------------------------- 35.1/228.5 MB 43.5 MB/s eta 0:00:05
#    ------ --------------------------------- 37.3/228.5 MB 40.9 MB/s eta 0:00:05
#    ------ --------------------------------- 39.5/228.5 MB 40.9 MB/s eta 0:00:05
#    ------- -------------------------------- 41.6/228.5 MB 54.7 MB/s eta 0:00:04
#    ------- -------------------------------- 43.7/228.5 MB 46.7 MB/s eta 0:00:04
#    ------- -------------------------------- 45.7/228.5 MB 43.5 MB/s eta 0:00:05
#    -------- ------------------------------- 47.9/228.5 MB 43.5 MB/s eta 0:00:05
#    -------- ------------------------------- 50.0/228.5 MB 43.5 MB/s eta 0:00:05
#    --------- ------------------------------ 52.0/228.5 MB 46.7 MB/s eta 0:00:04
#    --------- ------------------------------ 54.1/228.5 MB 43.7 MB/s eta 0:00:04
#    --------- ------------------------------ 56.1/228.5 MB 43.7 MB/s eta 0:00:04
#    ---------- ----------------------------- 58.3/228.5 MB 43.7 MB/s eta 0:00:04
#    ---------- ----------------------------- 60.3/228.5 MB 46.9 MB/s eta 0:00:04
#    ---------- ----------------------------- 62.5/228.5 MB 43.5 MB/s eta 0:00:04
#    ----------- ---------------------------- 64.4/228.5 MB 46.7 MB/s eta 0:00:04
#    ----------- ---------------------------- 66.7/228.5 MB 43.5 MB/s eta 0:00:04
#    ------------ --------------------------- 68.8/228.5 MB 43.7 MB/s eta 0:00:04
#    ------------ --------------------------- 71.0/228.5 MB 43.7 MB/s eta 0:00:04
#    ------------ --------------------------- 72.4/228.5 MB 40.9 MB/s eta 0:00:04
#    ------------- -------------------------- 74.5/228.5 MB 43.7 MB/s eta 0:00:04
#    ------------- -------------------------- 76.8/228.5 MB 40.9 MB/s eta 0:00:04
#    ------------- -------------------------- 78.9/228.5 MB 40.9 MB/s eta 0:00:04
#    -------------- ------------------------- 80.3/228.5 MB 38.5 MB/s eta 0:00:04
#    -------------- ------------------------- 81.8/228.5 MB 40.9 MB/s eta 0:00:04
#    -------------- ------------------------- 82.6/228.5 MB 36.4 MB/s eta 0:00:05
#    -------------- ------------------------- 83.7/228.5 MB 32.8 MB/s eta 0:00:05
#    -------------- ------------------------- 84.5/228.5 MB 29.7 MB/s eta 0:00:05
#    --------------- ------------------------ 86.7/228.5 MB 29.7 MB/s eta 0:00:05
#    --------------- ------------------------ 88.5/228.5 MB 29.7 MB/s eta 0:00:05
#    --------------- ------------------------ 90.4/228.5 MB 31.2 MB/s eta 0:00:05
#    ---------------- -----------------------
in c:\users\rrpalani\.conda\envs\pytorch_env\lib\site-packages (from grad-cam) (0.18.0)
# Collecting ttach (from grad-cam)
#   Downloading ttach-0.0.3-py3-none-any.whl.metadata (5.2 kB)
# Requirement already satisfied: tqdm in c:\users\rrpalani\.conda\envs\pytorch_env\lib\site-packages (from grad-cam) (4.66.2)
# Collecting opencv-python (from grad-cam)
#   Downloading opencv_python-4.9.0.80-cp37-abi3-win_amd64.whl.metadata (20 kB)
# Requirement already satisfied: matplotlib in c:\users\rrpalani\.conda\envs\pytorch_env\lib\site-packages (from grad-cam) (3.8.4)
# Requirement already satisfied: scikit-learn in c:\users\rrpalani\.conda\envs\pytorch_env\lib\site-packages (from grad-cam) (1.4.2)
# Requirement already satisfied: filelock in c:\users\rrpalani\.conda\envs\pytorch_env\lib\site-packages (from torch>=1.7.1->grad-cam) (3.13.1)
# Requirement already satisfied: typing-extensions>=4.8.0 in c:\users\rrpalani\.conda\envs\pytorch_env\lib\site-packages (from torch>=1.7.1->grad-cam) (4.11.0)
# Requirement already satisfied: sympy in c:\users\rrpalani\.conda\envs\pytorch_env\lib\site-packages (from torch>=1.7.1->grad-cam) (1.12)
# Requirement already satisfied: networkx in c:\users\rrpalani\.conda\envs\pytorch_env\lib\site-packages (from torch>=1.7.1->grad-cam) (3.1)
# Requirement already satisfied: jinja2 in c:\users\rrpalani\.conda\envs\pytorch_env\lib\site-packages (from torch>=1.7.1->grad-cam) (3.1.3)
# Requirement already satisfied: fsspec in c:\users\rrpalani\.conda\envs\pytorch_env\lib\site-packages (from torch>=1.7.1->grad-cam) (2024.3.1)
# Requirement already satisfied: mkl<=2021.4.0,>=2021.1.1 in c:\users\rrpalani\.conda\envs\pytorch_env\lib\site-packages (from torch>=1.7.1->grad-cam) (2021.4.0)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\rrpalani\.conda\envs\pytorch_env\lib\site-packages (from matplotlib->grad-cam) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in c:\users\rrpalani\.conda\envs\pytorch_env\lib\site-packages (from matplotlib->grad-cam) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\rrpalani\.conda\envs\pytorch_env\lib\site-packages (from matplotlib->grad-cam) (4.51.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\rrpalani\.conda\envs\pytorch_env\lib\site-packages (from matplotlib->grad-cam) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in c:\users\rrpalani\.conda\envs\pytorch_env\lib\site-packages (from matplotlib->grad-cam) (23.2)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\rrpalani\.conda\envs\pytorch_env\lib\site-packages (from matplotlib->grad-cam) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\rrpalani\.conda\envs\pytorch_env\lib\site-packages (from matplotlib->grad-cam) (2.8.2)
# Requirement already satisfied: scipy>=1.6.0 in c:\users\rrpalani\.conda\envs\pytorch_env\lib\site-packages (from scikit-learn->grad-cam) (1.13.0)
# Requirement already satisfied: joblib>=1.2.0 in c:\users\rrpalani\.conda\envs\pytorch_env\lib\site-packages (from scikit-learn->grad-cam) (1.4.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\rrpalani\.conda\envs\pytorch_env\lib\site-packages (from scikit-learn->grad-cam) (2.2.0)
# Requirement already satisfied: colorama in c:\users\rrpalani\.conda\envs\pytorch_env\lib\site-packages (from tqdm->grad-cam) (0.4.6)
# Requirement already satisfied: intel-openmp==2021.* in c:\users\rrpalani\.conda\envs\pytorch_env\lib\site-packages (from mkl<=2021.4.0,>=2021.1.1->torch>=1.7.1->grad-cam) (2021.4.0)
# Requirement already satisfied: tbb==2021.* in c:\users\rrpalani\.conda\envs\pytorch_env\lib\site-packages (from mkl<=2021.4.0,>=2021.1.1->torch>=1.7.1->grad-cam) (2021.12.0)
# Requirement already satisfied: six>=1.5 in c:\users\rrpalani\.conda\envs\pytorch_env\lib\site-packages (from python-dateutil>=2.7->matplotlib->grad-cam) (1.16.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\rrpalani\.conda\envs\pytorch_env\lib\site-packages (from jinja2->torch>=1.7.1->grad-cam) (2.1.3)
# Requirement already satisfied: mpmath>=0.19 in c:\users\rrpalani\.conda\envs\pytorch_env\lib\site-packages (from sympy->torch>=1.7.1->grad-cam) (1.3.0)
# Downloading opencv_python-4.9.0.80-cp37-abi3-win_amd64.whl (38.6 MB)
#    ---------------------------------------- 0.0/38.6 MB ? eta -:--:--
#     --------------------------------------- 0.7/38.6 MB 15.7 MB/s eta 0:00:03
#    - -------------------------------------- 1.4/38.6 MB 14.5 MB/s eta 0:00:03
#    - -------------------------------------- 1.9/38.6 MB 13.6 MB/s eta 0:00:03
#    -- ------------------------------------- 2.5/38.6 MB 13.4 MB/s eta 0:00:03
#    --- ------------------------------------ 3.1/38.6 MB 13.1 MB/s eta 0:00:03
#    --- ------------------------------------ 3.7/38.6 MB 13.1 MB/s eta 0:00:03
#    ---- ----------------------------------- 4.3/38.6 MB 13.1 MB/s eta 0:00:03
#    ---- ----------------------------------- 4.5/38.6 MB 13.1 MB/s eta 0:00:03
#    ----- ---------------------------------- 5.0/38.6 MB 11.7 MB/s eta 0:00:03
#    ----- ---------------------------------- 5.6/38.6 MB 11.9 MB/s eta 0:00:03
#    ------ --------------------------------- 6.2/38.6 MB 12.0 MB/s eta 0:00:03
#    ------- -------------------------------- 6.9/38.6 MB 12.2 MB/s eta 0:00:03
#    ------- -------------------------------- 7.5/38.6 MB 12.4 MB/s eta 0:00:03
#    -------- ------------------------------- 8.2/38.6 MB 12.5 MB/s eta 0:00:03
#    --------- ------------------------------ 8.7/38.6 MB 12.4 MB/s eta 0:00:03
#    --------- ------------------------------ 9.4/38.6 MB 12.5 MB/s eta 0:00:03
#    ---------- ----------------------------- 10.0/38.6 MB 12.6 MB/s eta 0:00:03
#    ----------- ---------------------------- 10.7/38.6 MB 12.6 MB/s eta 0:00:03
#    ----------- ---------------------------- 11.4/38.6 MB 12.6 MB/s eta 0:00:03
#    ------------ --------------------------- 12.1/38.6 MB 12.8 MB/s eta 0:00:03
#    ------------- -------------------------- 12.7/38.6 MB 12.8 MB/s eta 0:00:03
#    ------------- -------------------------- 13.3/38.6 MB 12.8 MB/s eta 0:00:02
#    -------------- ------------------------- 14.0/38.6 MB 13.1 MB/s eta 0:00:02
#    --------------- ------------------------ 14.7/38.6 MB 13.1 MB/s eta 0:00:02
#    --------------- ------------------------ 15.4/38.6 MB 13.9 MB/s eta 0:00:02
#    ---------------- ----------------------- 16.0/38.6 MB 13.9 MB/s eta 0:00:02
#    ----------------- ---------------------- 16.7/38.6 MB 13.9 MB/s eta 0:00:02
#    ----------------- ---------------------- 17.1/38.6 MB 13.6 MB/s eta 0:00:02
#    ------------------ --------------------- 17.8/38.6 MB 13.6 MB/s eta 0:00:02
#    ------------------- -------------------- 18.5/38.6 MB 13.9 MB/s eta 0:00:02
#    ------------------- -------------------- 18.9/38.6 MB 13.9 MB/s eta 0:00:02
#    -------------------- ------------------- 19.4/38.6 MB 13.6 MB/s eta 0:00:02
#    -------------------- ------------------- 20.1/38.6 MB 13.6 MB/s eta 0:00:02
#    --------------------- ------------------ 20.8/38.6 MB 13.6 MB/s eta 0:00:02
#    ---------------------- ----------------- 21.5/38.6 MB 13.6 MB/s eta 0:00:02
#    ----------------------- ---------------- 22.3/38.6 MB 13.6 MB/s eta 0:00:02
#    ----------------------- ---------------- 23.0/38.6 MB 13.6 MB/s eta 0:00:02
#    ------------------------ --------------- 23.7/38.6 MB 13.9 MB/s eta 0:00:02
#    ------------------------- -------------- 24.4/38.6 MB 13.9 MB/s eta 0:00:02
#    -------------------------- ------------- 25.1/38.6 MB 13.9 MB/s eta 0:00:01
#    -------------------------- ------------- 25.8/38.6 MB 13.9 MB/s eta 0:00:01
#    --------------------------- ------------ 26.5/38.6 MB 13.9 MB/s eta 0:00:01
#    ---------------------------- ----------- 27.1/38.6 MB 13.9 MB/s eta 0:00:01
#    ---------------------------- ----------- 27.9/38.6 MB 14.2 MB/s eta 0:00:01
#    ----------------------------- ---------- 28.6/38.6 MB 14.6 MB/s eta 0:00:01
#    ------------------------------ --------- 29.3/38.6 MB 14.9 MB/s eta 0:00:01
#    ------------------------------- -------- 30.1/38.6 MB 15.2 MB/s eta 0:00:01
#    ------------------------------- -------- 30.8/38.6 MB 15.2 MB/s eta 0:00:01
#    -------------------------------- ------- 31.5/38.6 MB 15.2 MB/s eta 0:00:01
#    --------------------------------- ------ 32.1/38.6 MB 14.9 MB/s eta 0:00:01
#    ---------------------------------- ----- 32.8/38.6 MB 14.9 MB/s eta 0:00:01
#    ---------------------------------- ----- 33.5/38.6 MB 14.9 MB/s eta 0:00:01
#    ----------------------------------- ---- 34.3/38.6 MB 14.9 MB/s eta 0:00:01
#    ------------------------------------ --- 34.9/38.6 MB 14.9 MB/s eta 0:00:01
#    ------------------------------------ --- 35.6/38.6 MB 14.9 MB/s eta 0:00:01
#    ------------------------------------- -- 36.3/38.6 MB 14.9 MB/s eta 0:00:01
#    -------------------------------------- - 37.0/38.6 MB 14.9 MB/s eta 0:00:01
#    ---------------------------------------  37.8/38.6 MB 15.2 MB/s eta 0:00:01
#    ---------------------------------------  38.5/38.6 MB 14.9 MB/s eta 0:00:01
#    ---------------------------------------  38.6/38.6 MB 14.9 MB/s eta 0:00:01
#    ---------------------------------------  38.6/38.6 MB 14.9 MB/s eta 0:00:01
#    ---------------------------------------  38.6/38.6 MB 14.9 MB/s eta 0:00:01
#    ---------------------------------------  38.6/38.6 MB 14.9 MB/s eta 0:00:01
#    ---------------------------------------  38.6/38.6 MB 14.9 MB/s eta 0:00:01
#    ---------------------------------------  38.6/38.6 MB 14.9 MB/s eta 0:00:01
#    ---------------------------------------  38.6/38.6 MB 14.9 MB/s eta 0:00:01
#    ---------------------------------------  38.6/38.6 MB 14.9 MB/s eta 0:00:01
#    ---------------------------------------  38.6/38.6 MB 14.9 MB/s eta 0:00:01
#    ---------------------------------------  38.6/38.6 MB 14.9 MB/s eta 0:00:01
#    ---------------------------------------  38.6/38.6 MB 14.9 MB/s eta 0:00:01
#    ---------------------------------------  38.6/38.6 MB 14.9 MB/s eta 0:00:01
#    ---------------------------------------  38.6/38.6 MB 14.9 MB/s eta 0:00:01
#    ---------------------------------------  38.6/38.6 MB 14.9 MB/s eta 0:00:01
#    ---------------------------------------- 38.6/38.6 MB 7.4 MB/s eta 0:00:00
# Downloading ttach-0.0.3-py3-none-any.whl (9.8 kB)
# Building wheels for collected packages: grad-cam
#   Building wheel for grad-cam (pyproject.toml): started
#   Building wheel for grad-cam (pyproject.toml): finished with status 'done'
#   Created wheel for grad-cam: filename=grad_cam-1.5.0-py3-none-any.whl size=38125 sha256=19601b2c6d5b7d42a0c3eea90a07ead5c6813ccbe80c68c4f777791254d3145c
#   Stored in directory: c:\users\rrpalani\appdata\local\pip\cache\wheels\5b\e5\3d\8548241d5cffe53ad1476c566a61ad9bf09cc61a9430f09726
# Successfully built grad-cam
# Installing collected packages: ttach, opencv-python, grad-cam
# Successfully installed grad-cam-1.5.0 opencv-python-4.9.0.80 ttach-0.0.3
# Note: you may need to restart the kernel to use updated packages.

# %%
# %pip install gradio
# Out:
# Collecting gradio
#   Downloading gradio-4.31.0-py3-none-any.whl.metadata (15 kB)
# Collecting aiofiles<24.0,>=22.0 (from gradio)
#   Downloading aiofiles-23.2.1-py3-none-any.whl.metadata (9.7 kB)
# Requirement already satisfied: altair<6.0,>=4.2.0 in c:\users\rrpalani\.conda\envs\pytorch_env\lib\site-packages (from gradio) (5.0.1)
# Collecting fastapi (from gradio)
#   Downloading fastapi-0.111.0-py3-none-any.whl.metadata (25 kB)
# Collecting ffmpy (from gradio)
#   Downloading ffmpy-0.3.2.tar.gz (5.5 kB)
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Collecting gradio-client==0.16.2 (from gradio)
#   Downloading gradio_client-0.16.2-py3-none-any.whl.metadata (7.1 kB)
# Collecting httpx>=0.24.1 (from gradio)
#   Downloading httpx-0.27.0-py3-none-any.whl.metadata (7.2 kB)
# Collecting huggingface-hub>=0.19.3 (from gradio)
#   Downloading huggingface_hub-0.23.0-py3-none-any.whl.metadata (12 kB)
# Collecting importlib-resources<7.0,>=1.3 (from gradio)
#   Downloading importlib_resources-6.4.0-py3-none-any.whl.metadata (3.9 kB)
# Requirement already satisfied: jinja2<4.0 in c:\users\rrpalani\.conda\envs\pytorch_env\lib\site-packages (from gradio) (3.1.3)
# Requirement already satisfied: markupsafe~=2.0 in c:\users\rrpalani\.conda\envs\pytorch_env\lib\site-packages (from gradio) (2.1.3)
# Requirement already satisfied: matplotlib~=3.0 in c:\users\rrpalani\.conda\envs\pytorch_env\lib\site-packages (from gradio) (3.8.4)
# Requirement already satisfied: numpy~=1.0 in c:\users\rrpalani\.conda\envs\pytorch_env\lib\site-packages (from gradio) (1.26.4)
# Collecting orjson~=3.0 (from gradio)
#   Downloading orjson-3.10.3-cp310-none-win_amd64.whl.metadata (50 kB)
#      ---------------------------------------- 0.0/50.9 kB ? eta -:--:--
#      -------------------------------- ------- 41.0/50.9 kB ? eta -:--:--
#      ---------------------------------------- 50.9/50.9 kB 1.3 MB/s eta 0:00:00
# Requirement already satisfied: packaging in c:\users\rrpalani\.conda\envs\pytorch_env\lib\site-packages (from gradio) (23.2)
# Requirement already satisfied: pandas<3.0,>=1.0 in c:\users\rrpalani\.conda\envs\pytorch_env\lib\site-packages (from gradio) (2.2.1)
# Requirement already satisfied: pillow<11.0,>=8.0 in c:\users\rrpalani\.conda\envs\pytorch_env\lib\site-packages (from gradio) (10.3.0)
# Collecting pydantic>=2.0 (from gradio)
#   Downloading pydantic-2.7.1-py3-none-any.whl.metadata (107 kB)
#      ---------------------------------------- 0.0/107.3 kB ? eta -:--:--
#      -------------------------------------- 107.3/107.3 kB 3.1 MB/s eta 0:00:00
# Collecting pydub (from gradio)
#   Downloading pydub-0.25.1-py2.py3-none-any.whl.metadata (1.4 kB)
# Collecting python-multipart>=0.0.9 (from gradio)
#   Downloading python_multipart-0.0.9-py3-none-any.whl.metadata (2.5 kB)
# Requirement already satisfied: pyyaml<7.0,>=5.0 in c:\users\rrpalani\.conda\envs\pytorch_env\lib\site-packages (from gradio) (6.0.1)
# Collecting ruff>=0.2.2 (from gradio)
#   Downloading ruff-0.4.4-py3-none-win_amd64.whl.metadata (24 kB)
# Collecting semantic-version~=2.0 (from gradio)
#   Downloading semantic_version-2.10.0-py2.py3-none-any.whl.metadata (9.7 kB)
# Collecting tomlkit==0.12.0 (from gradio)
#   Downloading tomlkit-0.12.0-py3-none-any.whl.metadata (2.7 kB)
# Collecting typer<1.0,>=0.12 (from gradio)
#   Downloading typer-0.12.3-py3-none-any.whl.metadata (15 kB)
# Requirement already satisfied: typing-extensions~=4.0 in c:\users\rrpalani\.conda\envs\pytorch_env\lib\site-packages (from gradio) (4.11.0)
# Requirement already satisfied: urllib3~=2.0 in c:\users\rrpalani\.conda\envs\pytorch_env\lib\site-packages (from gradio) (2.1.0)
# Collecting uvicorn>=0.14.0 (from gradio)
#   Downloading uvicorn-0.29.0-py3-none-any.whl.metadata (6.3 kB)
# Requirement already satisfied: fsspec in c:\users\rrpalani\.conda\envs\pytorch_env\lib\site-packages (from gradio-client==0.16.2->gradio) (2024.3.1)
# Collecting websockets<12.0,>=10.0 (from gradio-client==0.16.2->gradio)
#   Downloading websockets-11.0.3-cp310-cp310-win_amd64.whl.metadata (6.8 kB)
# Requirement already satisfied: jsonschema>=3.0 in c:\users\rrpalani\.conda\envs\pytorch_env\lib\site-packages (from altair<6.0,>=4.2.0->gradio) (4.19.2)
# Requirement already satisfied: toolz in c:\users\rrpalani\.conda\envs\pytorch_env\lib\site-packages (from altair<6.0,>=4.2.0->gradio) (0.12.0)
# Requirement already satisfied: anyio in c:\users\rrpalani\.conda\envs\pytorch_env\lib\site-packages (from httpx>=0.24.1->gradio) (4.2.0)
# Requirement already satisfied: certifi in c:\users\rrpalani\.conda\envs\pytorch_env\lib\site-packages (from httpx>=0.24.1->gradio) (2024.2.2)
# Collecting httpcore==1.* (from httpx>=0.24.1->gradio)
#   Downloading httpcore-1.0.5-py3-none-any.whl.metadata (20 kB)
# Requirement already satisfied: idna in c:\users\rrpalani\.conda\envs\pytorch_env\lib\site-packages (from httpx>=0.24.1->gradio) (3.7)
# Requirement already satisfied: sniffio in c:\users\rrpalani\.conda\envs\pytorch_env\lib\site-packages (from httpx>=0.24.1->gradio) (1.3.0)
# Collecting h11<0.15,>=0.13 (from httpcore==1.*->httpx>=0.24.1->gradio)
#   Downloading h11-0.14.0-py3-none-any.whl.metadata (8.2 kB)
# Requirement already satisfied: filelock in c:\users\rrpalani\.conda\envs\pytorch_env\lib\site-packages (from huggingface-hub>=0.19.3->gradio) (3.13.1)
# Requirement already satisfied: requests in c:\users\rrpalani\.conda\envs\pytorch_env\lib\site-packages (from huggingface-hub>=0.19.3->gradio) (2.31.0)
# Requirement already satisfied: tqdm>=4.42.1 in c:\users\rrpalani\.conda\envs\pytorch_env\lib\site-packages (from huggingface-hub>=0.19.3->gradio) (4.66.2)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\rrpalani\.conda\envs\pytorch_env\lib\site-packages (from matplotlib~=3.0->gradio) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in c:\users\rrpalani\.conda\envs\pytorch_env\lib\site-packages (from matplotlib~=3.0->gradio) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\rrpalani\.conda\envs\pytorch_env\lib\site-packages (from matplotlib~=3.0->gradio) (4.51.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\rrpalani\.conda\envs\pytorch_env\lib\site-packages (from matplotlib~=3.0->gradio) (1.4.4)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\rrpalani\.conda\envs\pytorch_env\lib\site-packages (from matplotlib~=3.0->gradio) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\rrpalani\.conda\envs\pytorch_env\lib\site-packages (from matplotlib~=3.0->gradio) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\rrpalani\.conda\envs\pytorch_env\lib\site-packages (from pandas<3.0,>=1.0->gradio) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\rrpalani\.conda\envs\pytorch_env\lib\site-packages (from pandas<3.0,>=1.0->gradio) (2023.3)
# Collecting annotated-types>=0.4.0 (from pydantic>=2.0->gradio)
#   Downloading annotated_types-0.6.0-py3-none-any.whl.metadata (12 kB)
# Collecting pydantic-core==2.18.2 (from pydantic>=2.0->gradio)
#   Downloading pydantic_core-2.18.2-cp310-none-win_amd64.whl.metadata (6.7 kB)
# Requirement already satisfied: click>=8.0.0 in c:\users\rrpalani\.conda\envs\pytorch_env\lib\site-packages (from typer<1.0,>=0.12->gradio) (8.1.7)
# Collecting shellingham>=1.3.0 (from typer<1.0,>=0.12->gradio)
#   Downloading shellingham-1.5.4-py2.py3-none-any.whl.metadata (3.5 kB)
# Requirement already satisfied: rich>=10.11.0 in c:\users\rrpalani\.conda\envs\pytorch_env\lib\site-packages (from typer<1.0,>=0.12->gradio) (13.3.5)
# Collecting starlette<0.38.0,>=0.37.2 (from fastapi->gradio)
#   Downloading starlette-0.37.2-py3-none-any.whl.metadata (5.9 kB)
# Collecting fastapi-cli>=0.0.2 (from fastapi->gradio)
#   Downloading fastapi_cli-0.0.3-py3-none-any.whl.metadata (7.0 kB)
# Requirement already satisfied: ujson!=4.0.2,!=4.1.0,!=4.2.0,!=4.3.0,!=5.0.0,!=5.1.0,>=4.0.1 in c:\users\rrpalani\.conda\envs\pytorch_env\lib\site-packages (from fastapi->gradio) (5.4.0)
# Collecting email_validator>=2.0.0 (from fastapi->gradio)
#   Downloading email_validator-2.1.1-py3-none-any.whl.metadata (26 kB)
# Requirement already satisfied: colorama in c:\users\rrpalani\.conda\envs\pytorch_env\lib\site-packages (from click>=8.0.0->typer<1.0,>=0.12->gradio) (0.4.6)
# Collecting dnspython>=2.0.0 (from email_validator>=2.0.0->fastapi->gradio)
#   Downloading dnspython-2.6.1-py3-none-any.whl.metadata (5.8 kB)
# Requirement already satisfied: attrs>=22.2.0 in c:\users\rrpalani\.conda\envs\pytorch_env\lib\site-packages (from jsonschema>=3.0->altair<6.0,>=4.2.0->gradio) (23.1.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in c:\users\rrpalani\.conda\envs\pytorch_env\lib\site-packages (from jsonschema>=3.0->altair<6.0,>=4.2.0->gradio) (2023.7.1)
# Requirement already satisfied: referencing>=0.28.4 in c:\users\rrpalani\.conda\envs\pytorch_env\lib\site-packages (from jsonschema>=3.0->altair<6.0,>=4.2.0->gradio) (0.30.2)
# Requirement already satisfied: rpds-py>=0.7.1 in c:\users\rrpalani\.conda\envs\pytorch_env\lib\site-packages (from jsonschema>=3.0->altair<6.0,>=4.2.0->gradio) (0.10.6)
# Requirement already satisfied: six>=1.5 in c:\users\rrpalani\.conda\envs\pytorch_env\lib\site-packages (from python-dateutil>=2.7->matplotlib~=3.0->gradio) (1.16.0)
# Requirement already satisfied: markdown-it-py<3.0.0,>=2.2.0 in c:\users\rrpalani\.conda\envs\pytorch_env\lib\site-packages (from rich>=10.11.0->typer<1.0,>=0.12->gradio) (2.2.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\rrpalani\.conda\envs\pytorch_env\lib\site-packages (from rich>=10.11.0->typer<1.0,>=0.12->gradio) (2.15.1)
# Requirement already satisfied: exceptiongroup>=1.0.2 in c:\users\rrpalani\.conda\envs\pytorch_env\lib\site-packages (from anyio->httpx>=0.24.1->gradio) (1.2.0)
# Collecting httptools>=0.5.0 (from uvicorn[standard]>=0.12.0->fastapi->gradio)
#   Downloading httptools-0.6.1-cp310-cp310-win_amd64.whl.metadata (3.7 kB)
# Collecting python-dotenv>=0.13 (from uvicorn[standard]>=0.12.0->fastapi->gradio)
#   Downloading python_dotenv-1.0.1-py3-none-any.whl.metadata (23 kB)
# Collecting watchfiles>=0.13 (from uvicorn[standard]>=0.12.0->fastapi->gradio)
#   Downloading watchfiles-0.21.0-cp310-none-win_amd64.whl.metadata (5.0 kB)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\rrpalani\.conda\envs\pytorch_env\lib\site-packages (from requests->huggingface-hub>=0.19.3->gradio) (2.0.4)
# Requirement already satisfied: mdurl~=0.1 in c:\users\rrpalani\.conda\envs\pytorch_env\lib\site-packages (from markdown-it-py<3.0.0,>=2.2.0->rich>=10.11.0->typer<1.0,>=0.12->gradio) (0.1.0)
# Downloading gradio-4.31.0-py3-none-any.whl (12.3 MB)
#    ---------------------------------------- 0.0/12.3 MB ? eta -:--:--
#    - -------------------------------------- 0.5/12.3 MB 14.9 MB/s eta 0:00:01
#    ----- ---------------------------------- 1.6/12.3 MB 16.8 MB/s eta 0:00:01
#    --------- ------------------------------ 2.8/12.3 MB 16.2 MB/s eta 0:00:01
#    ----------- ---------------------------- 3.6/12.3 MB 15.3 MB/s eta 0:00:01
#    -------------- ------------------------- 4.5/12.3 MB 15.8 MB/s eta 0:00:01
#    ----------------- ---------------------- 5.3/12.3 MB 15.5 MB/s eta 0:00:01
#    --------------------- ------------------ 6.5/12.3 MB 16.7 MB/s eta 0:00:01
#    ---------------------- ----------------- 6.9/12.3 MB 15.1 MB/s eta 0:00:01
#    ------------------------ --------------- 7.6/12.3 MB 15.3 MB/s eta 0:00:01
#    --------------------------- ------------ 8.4/12.3 MB 15.3 MB/s eta 0:00:01
#    ------------------------------- -------- 9.6/12.3 MB 14.2 MB/s eta 0:00:01
#    ----------------------------------- ---- 11.0/12.3 MB 13.6 MB/s eta 0:00:01
#    -------------------------------------- - 11.9/12.3 MB 13.6 MB/s eta 0:00:01
#    ---------------------------------------  12.3/12.3 MB 13.4 MB/s eta 0:00:01
#    ---------------------------------------  12.3/12.3 MB 13.4 MB/s eta 0:00:01
#    ---------------------------------------- 12.3/12.3 MB 11.3 MB/s eta 0:00:00
# Downloading gradio_client-0.16.2-py3-none-any.whl (315 kB)
#    ---------------------------------------- 0.0/315.5 kB ? eta -:--:--
#    ------------------------------------- - 307.2/315.5 kB 19.8 MB/s eta 0:00:01
#    ------------------------------------- - 307.2/315.5 kB 19.8 MB/s eta 0:00:01
#    ---------------------------------------- 315.5/315.5 kB 2.8 MB/s eta 0:00:00
# Downloading tomlkit-0.12.0-py3-none-any.whl (37 kB)
# Downloading aiofiles-23.2.1-py3-none-any.whl (15 kB)
# Downloading httpx-0.27.0-py3-none-any.whl (75 kB)
#    ---------------------------------------- 0.0/75.6 kB ? eta -:--:--
#    ------------------------------------- -- 71.7/75.6 kB ? eta -:--:--
#    ---------------------------------------- 75.6/75.6 kB 1.1 MB/s eta 0:00:00
# Downloading httpcore-1.0.5-py3-none-any.whl (77 kB)
#    ---------------------------------------- 0.0/77.9 kB ? eta -:--:--
#    ------------------------------------ --- 71.7/77.9 kB 4.1 MB/s eta 0:00:01
#    ---------------------------------------- 77.9/77.9 kB 621.0 kB/s eta 0:00:00
# Downloading huggingface_hub-0.23.0-py3-none-any.whl (401 kB)
#    ---------------------------------------- 0.0/401.2 kB ? eta -:--:--
#    --------------------------------------  399.4/401.2 kB 25.9 MB/s eta 0:00:01
#    ---------------------------------------- 401.2/401.2 kB 5.0 MB/s eta 0:00:00
# Downloading importlib_resources-6.4.0-py3-none-any.whl (38 kB)
# Downloading orjson-3.10.3-cp310-none-win_amd64.whl (138 kB)
#    ---------------------------------------- 0.0/138.8 kB ? eta -:--:--
#    ---------------------------------------- 138.8/138.8 kB 2.7 MB/s eta 0:00:00
# Downloading pydantic-2.7.1-py3-none-any.whl (409 kB)
#    ---------------------------------------- 0.0/409.3 kB ? eta -:--:--
#    --------------------------------------  399.4/409.3 kB 24.3 MB/s eta 0:00:01
#    ---------------------------------------- 409.3/409.3 kB 5.1 MB/s eta 0:00:00
# Downloading pydantic_core-2.18.2-cp310-none-win_amd64.whl (1.9 MB)
#    ---------------------------------------- 0.0/1.9 MB ? eta -:--:--
#    ---------- ----------------------------- 0.5/1.9 MB 16.0 MB/s eta 0:00:01
#    ------------------------ --------------- 1.2/1.9 MB 12.4 MB/s eta 0:00:01
#    ---------------------------------------  1.9/1.9 MB 13.5 MB/s eta 0:00:01
#    ---------------------------------------  1.9/1.9 MB 13.5 MB/s eta 0:00:01
#    ---------------------------------------- 1.9/1.9 MB 8.1 MB/s eta 0:00:00
# Downloading python_multipart-0.0.9-py3-none-any.whl (22 kB)
# Downloading ruff-0.4.4-py3-none-win_amd64.whl (8.4 MB)
#    ---------------------------------------- 0.0/8.4 MB ? eta -:--:--
#    ---- ----------------------------------- 1.0/8.4 MB 21.4 MB/s eta 0:00:01
#    ---------- ----------------------------- 2.3/8.4 MB 20.6 MB/s eta 0:00:01
#    ------------------ --------------------- 3.8/8.4 MB 20.4 MB/s eta 0:00:01
#    ------------------------ --------------- 5.1/8.4 MB 20.2 MB/s eta 0:00:01
#    ---------------------------- ----------- 6.0/8.4 MB 20.2 MB/s eta 0:00:01
#    --------------------------------- ------ 7.2/8.4 MB 20.8 MB/s eta 0:00:01
#    -------------------------------------- - 8.2/8.4 MB 19.4 MB/s eta 0:00:01
#    ---------------------------------------  8.4/8.4 MB 18.5 MB/s eta 0:00:01
#    ---------------------------------------  8.4/8.4 MB 18.5 MB/s eta 0:00:01
#    ---------------------------------------  8.4/8.4 MB 18.5 MB/s eta 0:00:01
#    ---------------------------------------- 8.4/8.4 MB 13.8 MB/s eta 0:00:00
# Downloading semantic_version-2.10.0-py2.py3-none-any.whl (15 kB)
# Downloading typer-0.12.3-py3-none-any.whl (47 kB)
#    ---------------------------------------- 0.0/47.2 kB ? eta -:--:--
#    ---------------------------------------- 47.2/47.2 kB 586.8 kB/s eta 0:00:00
# Downloading uvicorn-0.29.0-py3-none-any.whl (60 kB)
#    ---------------------------------------- 0.0/60.8 kB ? eta -:--:--
#    ---------------------------------------- 60.8/60.8 kB 1.6 MB/s eta 0:00:00
# Downloading fastapi-0.111.0-py3-none-any.whl (91 kB)
#    ---------------------------------------- 0.0/92.0 kB ? eta -:--:--
#    ----------------------------------- ---- 81.9/92.0 kB ? eta -:--:--
#    ---------------------------------------- 92.0/92.0 kB 1.7 MB/s eta 0:00:00
# Downloading pydub-0.25.1-py2.py3-none-any.whl (32 kB)
# Downloading annotated_types-0.6.0-py3-none-any.whl (12 kB)
# Downloading email_validator-2.1.1-py3-none-any.whl (30 kB)
# Downloading fastapi_cli-0.0.3-py3-none-any.whl (9.2 kB)
# Downloading h11-0.14.0-py3-none-any.whl (58 kB)
#    ---------------------------------------- 0.0/58.3 kB ? eta -:--:--
#    ---------------------------------------- 58.3/58.3 kB 1.5 MB/s eta 0:00:00
# Downloading shellingham-1.5.4-py2.py3-none-any.whl (9.8 kB)
# Downloading starlette-0.37.2-py3-none-any.whl (71 kB)
#    ---------------------------------------- 0.0/71.9 kB ? eta -:--:--
#    ---------------------------------------- 71.9/71.9 kB 2.0 MB/s eta 0:00:00
# Downloading websockets-11.0.3-cp310-cp310-win_amd64.whl (124 kB)
#    ---------------------------------------- 0.0/124.7 kB ? eta -:--:--
#    ---------------------------------------- 124.7/124.7 kB 3.7 MB/s eta 0:00:00
# Downloading dnspython-2.6.1-py3-none-any.whl (307 kB)
#    ---------------------------------------- 0.0/307.7 kB ? eta -:--:--
#    ---------------------------------------- 307.7/307.7 kB 6.3 MB/s eta 0:00:00
# Downloading httptools-0.6.1-cp310-cp310-win_amd64.whl (58 kB)
#    ---------------------------------------- 0.0/58.2 kB ? eta -:--:--
#    ---------------------------------------- 58.2/58.2 kB 1.5 MB/s eta 0:00:00
# Downloading python_dotenv-1.0.1-py3-none-any.whl (19 kB)
# Downloading watchfiles-0.21.0-cp310-none-win_amd64.whl (279 kB)
#    ---------------------------------------- 0.0/279.7 kB ? eta -:--:--
#    ---------------------------------------- 279.7/279.7 kB 8.7 MB/s eta 0:00:00
# Building wheels for collected packages: ffmpy
#   Building wheel for ffmpy (setup.py): started
#   Building wheel for ffmpy (setup.py): finished with status 'done'
#   Created wheel for ffmpy: filename=ffmpy-0.3.2-py3-none-any.whl size=5607 sha256=d3ee9de38664687b90137580eedd6c8c076eebee27a23dd2bab03b4e8a1bb035
#   Stored in directory: c:\users\rrpalani\appdata\local\pip\cache\wheels\bd\65\9a\671fc6dcde07d4418df0c592f8df512b26d7a0029c2a23dd81
# Successfully built ffmpy
# Installing collected packages: pydub, ffmpy, websockets, tomlkit, shellingham, semantic-version, ruff, python-multipart, python-dotenv, pydantic-core, orjson, importlib-resources, httptools, h11, dnspython, annotated-types, aiofiles, watchfiles, uvicorn, starlette, pydantic, huggingface-hub, httpcore, email_validator, typer, httpx, gradio-client, fastapi-cli, fastapi, gradio
#   Attempting uninstall: tomlkit
#     Found existing installation: tomlkit 0.11.1
#     Uninstalling tomlkit-0.11.1:
#       Successfully uninstalled tomlkit-0.11.1
# Successfully installed aiofiles-23.2.1 annotated-types-0.6.0 dnspython-2.6.1 email_validator-2.1.1 fastapi-0.111.0 fastapi-cli-0.0.3 ffmpy-0.3.2 gradio-4.31.0 gradio-client-0.16.2 h11-0.14.0 httpcore-1.0.5 httptools-0.6.1 httpx-0.27.0 huggingface-hub-0.23.0 importlib-resources-6.4.0 orjson-3.10.3 pydantic-2.7.1 pydantic-core-2.18.2 pydub-0.25.1 python-dotenv-1.0.1 python-multipart-0.0.9 ruff-0.4.4 semantic-version-2.10.0 shellingham-1.5.4 starlette-0.37.2 tomlkit-0.12.0 typer-0.12.3 uvicorn-0.29.0 watchfiles-0.21.0 websockets-11.0.3
# Note: you may need to restart the kernel to use updated packages.

# %%
# %pip install opencv-python-headless
# Out:
# Collecting opencv-python-headlessNote: you may need to restart the kernel to use updated packages.
#
#   Downloading opencv_python_headless-4.9.0.80-cp37-abi3-win_amd64.whl.metadata (20 kB)
# Requirement already satisfied: numpy>=1.21.2 in c:\users\rrpalani\.conda\envs\pytorch_env\lib\site-packages (from opencv-python-headless) (1.26.4)
# Downloading opencv_python_headless-4.9.0.80-cp37-abi3-win_amd64.whl (38.5 MB)
#    ---------------------------------------- 0.0/38.5 MB ? eta -:--:--
#    ---------------------------------------- 0.0/38.5 MB ? eta -:--:--
#    ---------------------------------------- 0.0/38.5 MB ? eta -:--:--
#    ---------------------------------------- 0.1/38.5 MB 871.5 kB/s eta 0:00:45
#    ---------------------------------------- 0.1/38.5 MB 871.5 kB/s eta 0:00:45
#    ---------------------------------------- 0.1/38.5 MB 871.5 kB/s eta 0:00:45
#    ---------------------------------------- 0.4/38.5 MB 2.0 MB/s eta 0:00:20
#    - -------------------------------------- 1.3/38.5 MB 5.0 MB/s eta 0:00:08
#    --- ------------------------------------ 3.5/38.5 MB 11.9 MB/s eta 0:00:03
#    ----- ---------------------------------- 5.7/38.5 MB 16.6 MB/s eta 0:00:02
#    ------- -------------------------------- 7.5/38.5 MB 19.1 MB/s eta 0:00:02
#    ---------- ----------------------------- 10.0/38.5 MB 22.8 MB/s eta 0:00:02
#    ----------- ---------------------------- 10.6/38.5 MB 40.9 MB/s eta 0:00:01
#    ----------- ---------------------------- 10.6/38.5 MB 40.9 MB/s eta 0:00:01
#    ----------- ---------------------------- 11.1/38.5 MB 28.5 MB/s eta 0:00:01
#    -------------- ------------------------- 14.2/38.5 MB 31.2 MB/s eta 0:00:01
#    ----------------- ---------------------- 17.2/38.5 MB 34.4 MB/s eta 0:00:01
#    --------------------- ------------------ 20.3/38.5 MB 36.4 MB/s eta 0:00:01
#    ----------------------- ---------------- 22.7/38.5 MB 59.5 MB/s eta 0:00:01
#    ------------------------- -------------- 24.1/38.5 MB 59.5 MB/s eta 0:00:01
#    ------------------------- -------------- 24.6/38.5 MB 46.7 MB/s eta 0:00:01
#    -------------------------- ------------- 25.4/38.5 MB 40.9 MB/s eta 0:00:01
#    -------------------------- ------------- 25.9/38.5 MB 34.4 MB/s eta 0:00:01
#    --------------------------- ------------ 26.4/38.5 MB 31.2 MB/s eta 0:00:01
#    ---------------------------- ----------- 27.8/38.5 MB 29.7 MB/s eta 0:00:01
#    ----------------------------- ---------- 28.7/38.5 MB 26.2 MB/s eta 0:00:01
#    -------------------------------- ------- 31.3/38.5 MB 26.2 MB/s eta 0:00:01
#    ---------------------------------- ----- 33.4/38.5 MB 26.2 MB/s eta 0:00:01
#    ------------------------------------ --- 35.5/38.5 MB 31.2 MB/s eta 0:00:01
#    -------------------------------------- - 37.6/38.5 MB 40.9 MB/s eta 0:00:01
#    ---------------------------------------  38.5/38.5 MB 50.1 MB/s eta 0:00:01
#    ---------------------------------------  38.5/38.5 MB 50.1 MB/s eta 0:00:01
#    ---------------------------------------  38.5/38.5 MB 50.1 MB/s eta 0:00:01
#    ---------------------------------------  38.5/38.5 MB 50.1 MB/s eta 0:00:01
#    ---------------------------------------  38.5/38.5 MB 50.1 MB/s eta 0:00:01
#    ---------------------------------------  38.5/38.5 MB 50.1 MB/s eta 0:00:01
#    ---------------------------------------  38.5/38.5 MB 50.1 MB/s eta 0:00:01
#    ---------------------------------------  38.5/38.5 MB 50.1 MB/s eta 0:00:01
#    ---------------------------------------- 38.5/38.5 MB 17.2 MB/s eta 0:00:00
# Installing collected packages: opencv-python-headless
# Successfully installed opencv-python-headless-4.9.0.80

# %%
# !git clone https://github.com/rajayourfriend/EraV2/
# !cp ./EraV2/S14/*.py .
# !cp ./EraV2/S14/*.jpg .
# Out:
# Cloning into 'EraV2'...
# Updating files:  54% (179/328)
# Updating files:  55% (181/328)
# Updating files:  56% (184/328)
# Updating files:  57% (187/328)
# Updating files:  58% (191/328)
# Updating files:  59% (194/328)
# Updating files:  60% (197/328)
# Updating files:  61% (201/328)
# Updating files:  62% (204/328)
# Updating files:  63% (207/328)
# Updating files:  64% (210/328)
# Updating files:  65% (214/328)
# Updating files:  66% (217/328)
# Updating files:  67% (220/328)
# Updating files:  68% (224/328)
# Updating files:  69% (227/328)
# Updating files:  70% (230/328)
# Updating files:  71% (233/328)
# Updating files:  72% (237/328)
# Updating files:  73% (240/328)
# Updating files:  74% (243/328)
# Updating files:  75% (246/328)
# Updating files:  76% (250/328)
# Updating files:  77% (253/328)
# Updating files:  78% (256/328)
# Updating files:  79% (260/328)
# Updating files:  80% (263/328)
# Updating files:  80% (265/328)
# Updating files:  81% (266/328)
# Updating files:  82% (269/328)
# Updating files:  83% (273/328)
# Updating files:  84% (276/328)
# Updating files:  85% (279/328)
# Updating files:  86% (283/328)
# Updating files:  87% (286/328)
# Updating files:  87% (287/328)
# Updating files:  88% (289/328)
# Updating files:  88% (290/328)
# Updating files:  89% (292/328)
# Updating files:  90% (296/328)
# Updating files:  91% (299/328)
# Updating files:  92% (302/328)
# Updating files:  93% (306/328)
# Updating files:  94% (309/328)
# Updating files:  94% (310/328)
# Updating files:  94% (311/328)
# Updating files:  95% (312/328)
# Updating files:  96% (315/328)
# Updating files:  97% (319/328)
# Updating files:  98% (322/328)
# Updating files:  99% (325/328)
# Updating files: 100% (328/328)
# Updating files: 100% (328/328), done.
# 'cp' is not recognized as an internal or external command,
# operable program or batch file.
# 'cp' is not recognized as an internal or external command,
# operable program or batch file.

# %%
if save1_or_load0 == False:
  # !cp ./EraV2/S14/weights_92.ckpt weights.ckpt
wt_fname = "weights.ckpt" # weights file name to load
# Out:
# 'cp' is not recognized as an internal or external command,
# operable program or batch file.

# %%
import os
import torch
import torchvision
from torchvision import datasets, transforms, utils
from pl_bolts.datamodules import CIFAR10DataModule
from pl_bolts.transforms.dataset_normalizations import cifar10_normalization
from pytorch_lightning import LightningModule, Trainer, seed_everything
from pytorch_lightning.callbacks import LearningRateMonitor
from pytorch_lightning.callbacks.progress import TQDMProgressBar
from pytorch_lightning.loggers import CSVLogger
from torch.optim.lr_scheduler import OneCycleLR
from torch.optim.swa_utils import AveragedModel, update_bn
from torchmetrics.functional import accuracy
import pandas as pd
import seaborn as sn
import torch.nn as nn
import torch.nn.functional as F
# from IPython.core.display import display
import misclas_helper
import gradcam_helper
import lightningmodel
import trainsave_loadtest
from misclas_helper import display_cifar_misclassified_data
from gradcam_helper import display_gradcam_output
from misclas_helper import get_misclassified_data2
from misclas_helper import classify_images
from lightningmodel import LitResnet
from trainsave_loadtest import ts_lt

model, trainer = ts_lt(save1_or_load0, Epochs = 1, wt_fname = "weights.ckpt") # Train and Save Vs Load and Test

# %%
device = torch.device("cpu")

# Get the misclassified data from test dataset
misclassified_data = misclas_helper.get_misclassified_data2(model, device, 20)

# %%
import numpy as np
import gradio as gr
from PIL import Image
from pytorch_grad_cam import GradCAM
from pytorch_grad_cam.utils.image import show_cam_on_image
from torchvision import datasets, transforms, utils
import misclas_helper
from misclas_helper import classify_images

fileName = None

inv_normalize = transforms.Normalize(
  mean=[-0.50/0.23, -0.50/0.23, -0.50/0.23],
  std=[1/0.23, 1/0.23, 1/0.23]
)

def hello(DoYouWantToShowMisClassifiedImages, HowManyImages):
  if(DoYouWantToShowMisClassifiedImages.lower() == "yes"):
    fileName = misclas_helper.display_cifar_misclassified_data(misclassified_data, classes, inv_normalize, number_of_samples=HowManyImages)
    return Image.open(fileName)
  else:
    return None
misClass_demo = gr.Interface(
    fn = hello,
    inputs=[ gr.Textbox(label="Do you want to show misClassified images ?", placeholder="Yes / yes / YES", lines=1),
             gr.Slider(0, 20, step=5, label = "How many images ?")],
    outputs=['image'],
    title="Misclassified Images",
    description="If your answer to the question is yes, then only it works !",
)


############

targets = None
device = torch.device("cpu")
classes = ('plane', 'car', 'bird', 'cat', 'deer',
           'dog', 'frog', 'horse', 'ship', 'truck', 'No Image')


def inference(DoYouWantToShowGradCAMMedImages, HowManyImages, WhichLayer, transparency):
  if(DoYouWantToShowGradCAMMedImages.lower() == "yes"):
    if(WhichLayer == -1):
      target_layers = [model.model.resNetLayer2Part2[-1]]
    elif(WhichLayer == -2):
      target_layers = [model.model.resNetLayer2Part1[-1]]
    elif(WhichLayer == -3):
      target_layers = [model.model.Layer3[-1]]
    fileName = gradcam_helper.display_gradcam_output(misclassified_data, classes, inv_normalize, model.model, target_layers, targets, number_of_samples=HowManyImages, transparency=0.70)
    return Image.open(fileName)

gradCAM_demo = gr.Interface(
    fn=inference,
        #DoYouWantToShowGradCAMMedImages, HowManyImages, WhichLayer, transparency
    inputs=[ gr.Textbox(label="Do you want to show gradCammed images ?", placeholder="Yes / yes / YES", lines=1),
             gr.Slider(0, 20, step=5, label = "How many images ?"),
             gr.Slider(-3, -1, value = -1, step=1, label = "Which layer ?"),
             gr.Slider(0, 1, value = 0.7, label = "Overall Opacity of the Overlay")],
    outputs=['image'],
    title="GradCammed Images",
    description="If your answer to the question is yes, then only it works !",
)


############

def ImageInputter(img0, img1, img2, img3, img4, img5, img6, img7, img8, img9):
  list_images = [img0, img1, img2, img3, img4, img5, img6, img7, img8, img9]
  classified_data = classify_images(list_images, model.model, device)
  img_out = []
  pred_out = []
  for img, pred in classified_data:
    img_out.append(img)
    pred_out.append(pred)
  return classes[pred_out[0]], img_out[0], classes[pred_out[1]], img_out[1], classes[pred_out[2]], img_out[2], classes[pred_out[3]], img_out[3], classes[pred_out[4]], img_out[4], classes[pred_out[5]], img_out[5], classes[pred_out[6]], img_out[6], classes[pred_out[7]], img_out[7], classes[pred_out[8]], img_out[8], classes[pred_out[9]], img_out[9]

imageInputter_demo = gr.Interface(
    ImageInputter,
    [
        "image","image","image","image","image","image","image","image","image","image"
    ],
    [
        gr.Textbox("text", label = "pred 0"), gr.Image("image", label = "img 0"),
        gr.Textbox("text", label = "pred 1"), gr.Image("image", label = "img 1"),
        gr.Textbox("text", label = "pred 2"), gr.Image("image", label = "img 2"),
        gr.Textbox("text", label = "pred 3"), gr.Image("image", label = "img 3"),
        gr.Textbox("text", label = "pred 4"), gr.Image("image", label = "img 4"),
        gr.Textbox("text", label = "pred 5"), gr.Image("image", label = "img 5"),
        gr.Textbox("text", label = "pred 6"), gr.Image("image", label = "img 6"),
        gr.Textbox("text", label = "pred 7"), gr.Image("image", label = "img 7"),
        gr.Textbox("text", label = "pred 8"), gr.Image("image", label = "img 8"),
        gr.Textbox("text", label = "pred 9"), gr.Image("image", label = "img 9")
    ],
    examples=[
        ["bird.jpg", "car.jpg", "cat.jpg", "deer.jpg", "dog.jpg", "frog.jpg", "horse.jpg", "plane.jpg", "ship.jpg"],
        [None, None, None, None, "truck.jpg", None, None, None, None],
    ],
    title="Max 10 images input Classifier",
    description="Here's a sample image inputter. Allows you to feed in 10 images and display them with classification result. You may drag and drop images from bottom examples to the input feeders. You may copy and paste the images from examples to the input feeders. You may double click on a row of images from examples to get them filled in input feeders.",
)


############


demo = gr.TabbedInterface(
    interface_list = [misClass_demo, gradCAM_demo, imageInputter_demo],
    tab_names = ["MisClassified Images", "GradCAMMed Images", "10 images inputter"]
)

demo.launch(debug=True)
